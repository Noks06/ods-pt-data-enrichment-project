# %% [markdown]
# # PROJECT 3 PART 2
# NOKUTHULA MCHUNU

# %% [markdown]
# I) Normalizing Genres - Overview
#
# In order to normalize genres, we will need to:
#
# Convert the single string of genres from title basics into 2 new tables.
# title_genres: with the columns:
#
# tconst
# genre_id
# genres:
#
# genre_id
# genre_name
# Creating these tables will be a multi-step process.
#
# Getting a list of all individual genres.
# Create a new title_genres table with with the movie ids duplicated, once for each genre that a movie belongs to.
# Create a mapper dictionary with numeric ids for each genre.
# Use the mapper dictionary to replace the string genres in title_genres with numeric genre_ids.
# Convert the mapper dictionary into a final genres table with the numeric genre_id and the string genre.

# %%
# Import relevent liberies 
import pandas as pd 
import numpy as ny

# %%
# Loading basic-rating
basic = pd.read_csv('Data/title_basics.csv.gz')
basic.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0070596     movie                                  Socialist Realism
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                     El realismo socialista        0       2023      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4              78                   Drama

# %% [markdown]
# ##1. Getting a List of Unique Genres

# %%
## create a col with a list of genres
basic['genres_split'] = basic['genres'].str.split(',')
basic['genres_split']
# Out:
# 0           [Comedy, Fantasy, Romance]
# 1                              [Drama]
# 2                              [Drama]
# 3                              [Drama]
# 4                              [Drama]
#                      ...
# 91448                          [Drama]
# 91449         [Comedy, Drama, Fantasy]
# 91450                          [Drama]
# 91451    [Action, Adventure, Thriller]
# 91452                 [Drama, History]
# Name: genres_split, Length: 91453, dtype: object

# %% [markdown]
# We will then use .explode() to separate the list of genres into new rows: one row for each genre a movie belonged to.

# %%
#Use explode function
exploded_genres = basic.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0068865     movie                                Lives of Performers
# ...          ...       ...                                                ...
# 91451  tt9916190     movie                                          Safeguard
# 91451  tt9916190     movie                                          Safeguard
# 91451  tt9916190     movie                                          Safeguard
# 91452  tt9916362     movie                                              Coven
# 91452  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El tango del viudo y su espejo deformante        0       2020      NaN
# 2                            Lives of Performers        0       2016      NaN
# ...                                          ...      ...        ...      ...
# 91451                                  Safeguard        0       2020      NaN
# 91451                                  Safeguard        0       2020      NaN
# 91451                                  Safeguard        0       2020      NaN
# 91452                                   Akelarre        0       2020      NaN
# 91452                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                  90                      Drama        Drama
# ...               ...                        ...          ...
# 91451              95  Action,Adventure,Thriller       Action
# 91451              95  Action,Adventure,Thriller    Adventure
# 91451              95  Action,Adventure,Thriller     Thriller
# 91452              92              Drama,History        Drama
# 91452              92              Drama,History      History
#
# [170868 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# ## 2. Create a new title_genres table

# %%
# Creating a new table from Genres
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0068865        Drama

# %% [markdown]
# ## 3. Create a genre mapper dictionary to replace string genres with integers

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
genre_id_map = dict(zip(unique_genres,range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %% [markdown]
# ## 4. Replace the string genres in title_genres with the new integer ids.

# %%
## make new integer genre_id and drop string genres
#basic['genre_id'] = basic['genres_split'].map(genre_map)
genre_ints
# Out:
# range(0, 25)

# %%
## make new integer genre_id and drop string genres
#basic['genre_id'] = basic['genres_split'].map(genre_map)
#df = df.drop(columns='genres_split')

# %%
genre_lookup =pd.DataFrame({'genre_name':genre_id_map.keys(),
                            'genre_Id' :genre_id_map.values()})
genre_lookup
# Out:
#     genre_name  genre_Id
# 0       Action         0
# 1        Adult         1
# 2    Adventure         2
# 3    Animation         3
# 4    Biography         4
# 5       Comedy         5
# 6        Crime         6
# 7        Drama         7
# 8       Family         8
# 9      Fantasy         9
# 10   Game-Show        10
# 11     History        11
# 12      Horror        12
# 13       Music        13
# 14     Musical        14
# 15     Mystery        15
# 16        News        16
# 17  Reality-TV        17
# 18     Romance        18
# 19      Sci-Fi        19
# 20       Sport        20
# 21   Talk-Show        21
# 22    Thriller        22
# 23         War        23
# 24     Western        24

# %% [markdown]
# II) Saving the MySQL tables with tconst as the primary key.

# %%
basic.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0070596     movie                                  Socialist Realism
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                     El realismo socialista        0       2023      NaN
#
#    runtimeMinutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2              90                   Drama                     [Drama]
# 3             122                   Drama                     [Drama]
# 4              78                   Drama                     [Drama]

# %%
basic = basic[['tconst','primaryTitle','startYear','runtimeMinutes']]
basic.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0068865                                Lives of Performers       2016
# 3  tt0069049                         The Other Side of the Wind       2018
# 4  tt0070596                                  Socialist Realism       2023
#
#    runtimeMinutes
# 0             118
# 1              70
# 2              90
# 3             122
# 4              78

# %% [markdown]
# ## Loading Title Ratings

# %%
ratings = pd.read_csv('Data/title_rating.csv.gz')
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2002
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2677
# 3  tt0000006            5.0       183
# 4  tt0000007            5.4       838

# %% [markdown]
# ## Loading TMDB API Results

# %%
# loading `TMBD Api Result 
tmdb_Api = pd.read_csv('Data/Datatmdb_results_combined.csv.gz')
tmdb_Api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2620 non-null   object
#  1   adult                  2618 non-null   float64
#  2   backdrop_path          1467 non-null   object
#  3   belongs_to_collection  212 non-null    object
#  4   budget                 2618 non-null   float64
#  5   genres                 2618 non-null   object
#  6   homepage               172 non-null    object
#  7   id                     2618 non-null   float64
#  8   original_language      2618 non-null   object
#  9   original_title         2618 non-null   object
#  10  overview               2566 non-null   object
#  11  popularity             2618 non-null   float64
#  12  poster_path            2376 non-null   object
#  13  production_companies   2618 non-null   object
#  14  production_countries   2618 non-null   object
#  15  release_date           2595 non-null   object
#  16  revenue                2618 non-null   float64
#  17  runtime                2618 non-null   float64
#  18  spoken_languages       2618 non-null   object
#  19  status                 2618 non-null   object
#  20  tagline                1129 non-null   object
#  21  title                  2618 non-null   object
#  22  video                  2618 non-null   float64
#  23  vote_average           2618 non-null   float64
#  24  vote_count             2618 non-null   float64
#  25  certification          815 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 532.3+ KB

# %%
tmdb_Api =tmdb_Api[['imdb_id','budget','revenue','certification']]
tmdb_Api.head()
# Out:
#      imdb_id      budget     revenue certification
# 0          0         NaN         NaN           NaN
# 1  tt0113026  10000000.0         0.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694    150000.0  14204632.0            PG

# %%
# checking datatype tmdb_Api
tmdb_Api.dtypes
# Out:
# imdb_id           object
# budget           float64
# revenue          float64
# certification     object
# dtype: object

# %%
# Checking datatype for ratings
ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
# Checking datatype for basic
basic.dtypes
# Out:
# tconst            object
# primaryTitle      object
# startYear          int64
# runtimeMinutes     int64
# dtype: object

# %% [markdown]
# # Creating database

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
connection_str = "mysql+pymysql://root:Lwanda09/movies"

# %%
engine = create_engine(connection_str)
engine
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 engine = create_engine(connection_str)
#       2 engine
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:375, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     368     if m in kwargs:
#     369         _warn_with_version(
#     370             messages[m],
#     371             versions[m],
#     372             version_warnings[m],
#     373             stacklevel=3,
#     374         )
# --> 375 return fn(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/create.py:514, in create_engine(url, **kwargs)
#     511 kwargs.pop("empty_in_strategy", None)
#     513 # create url.URL object
# --> 514 u = _url.make_url(url)
#     516 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     518 entrypoint = u._get_entrypoint()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/url.py:738, in make_url(name_or_url)
#     725 """Given a string or unicode instance, produce a new URL instance.
#     726
#     727
#    (...)
#     734
#     735 """
#     737 if isinstance(name_or_url, util.string_types):
# --> 738     return _parse_url(name_or_url)
#     739 else:
#     740     return name_or_url
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/url.py:794, in _parse_url(name)
#     791     name = components.pop("name")
#     793     if components["port"]:
# --> 794         components["port"] = int(components["port"])
#     796     return URL.create(name, **components)
#     798 else:
#
# ValueError: invalid literal for int() with base 10: 'Lwanda09'

# %%
# Check if the database exists. If not, create it.
if database_exists(connection_str) == False:
  create_database(connection_str)
else:
  print('The database already exists')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3371, in Engine._wrap_pool_connect(self, fn, connection)
#    3370 try:
# -> 3371     return fn()
#    3372 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:493, in _ConnectionRecord.checkout(cls, pool)
#     491 @classmethod
#     492 def checkout(cls, pool):
# --> 493     rec = pool._do_get()
#     494     try:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     144 except:
# --> 145     with util.safe_reraise():
#     146         self._dec_overflow()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:273, in Pool._create_connection(self)
#     271 """Called by subclasses to create a new ConnectionRecord."""
# --> 273 return _ConnectionRecord(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:388, in _ConnectionRecord.__init__(self, pool, connect)
#     387 if connect:
# --> 388     self.__connect()
#     389 self.finalize_callback = deque()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:690, in _ConnectionRecord.__connect(self)
#     689 except BaseException as e:
# --> 690     with util.safe_reraise():
#     691         pool.logger.debug("Error on connect(): %s", e)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:686, in _ConnectionRecord.__connect(self)
#     685 self.starttime = time.time()
# --> 686 self.dbapi_connection = connection = pool._invoke_creator(self)
#     687 pool.logger.debug("Created new connection %r", connection)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/create.py:574, in create_engine.<locals>.connect(connection_record)
#     573             return connection
# --> 574 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351 else:
# --> 352     self.connect()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:636, in Connection.connect(self, sock)
#     635 self._get_server_information()
# --> 636 self._request_authentication()
#     638 if self.sql_mode is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:933, in Connection._request_authentication(self)
#     932 if self._auth_plugin_name == "caching_sha2_password":
# --> 933     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     934 elif self._auth_plugin_name == "sha256_password":
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/_auth.py:266, in caching_sha2_password_auth(conn, pkt)
#     265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266 pkt = _roundtrip(conn, data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/_auth.py:120, in _roundtrip(conn, send_data)
#     119 conn.write_packet(send_data)
# --> 120 pkt = conn._read_packet()
#     121 pkt.check_error()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Check if the database exists. If not, create it.
# ----> 2 if database_exists(connection_str) == False:
#       3   create_database(connection_str)
#       4 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy_utils/functions/database.py:498, in database_exists(url)
#     495     engine = sa.create_engine(url)
#     496     text = ("SELECT SCHEMA_NAME FROM INFORMATION_SCHEMA.SCHEMATA "
#     497             "WHERE SCHEMA_NAME = '%s'" % database)
# --> 498     return bool(_get_scalar_result(engine, sa.text(text)))
#     500 elif dialect_name == 'sqlite':
#     501     url = _set_url_database(url, database=None)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy_utils/functions/database.py:442, in _get_scalar_result(engine, sql)
#     441 def _get_scalar_result(engine, sql):
# --> 442     with engine.connect() as conn:
#     443         return conn.scalar(sql)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3325, in Engine.connect(self, close_with_result)
#    3310 def connect(self, close_with_result=False):
#    3311     """Return a new :class:`_engine.Connection` object.
#    3312
#    3313     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3322
#    3323     """
# -> 3325     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3404, in Engine.raw_connection(self, _connection)
#    3382 def raw_connection(self, _connection=None):
#    3383     """Return a "raw" DBAPI connection from the connection pool.
#    3384
#    3385     The returned object is a proxied version of the DBAPI
#    (...)
#    3402
#    3403     """
# -> 3404     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3374, in Engine._wrap_pool_connect(self, fn, connection)
#    3372 except dialect.dbapi.Error as e:
#    3373     if connection is None:
# -> 3374         Connection._handle_dbapi_exception_noconnection(
#    3375             e, dialect, self
#    3376         )
#    3377     else:
#    3378         util.raise_(
#    3379             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3380         )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2208, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2206     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2207 elif should_wrap:
# -> 2208     util.raise_(
#    2209         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2210     )
#    2211 else:
#    2212     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3371, in Engine._wrap_pool_connect(self, fn, connection)
#    3369 dialect = self.dialect
#    3370 try:
# -> 3371     return fn()
#    3372 except dialect.dbapi.Error as e:
#    3373     if connection is None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     319 def connect(self):
#     320     """Return a DBAPI connection from the pool.
#     321
#     322     The connection is instrumented such that when its
#    (...)
#     325
#     326     """
# --> 327     return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     891 @classmethod
#     892 def _checkout(cls, pool, threadconns=None, fairy=None):
#     893     if not fairy:
# --> 894         fairy = _ConnectionRecord.checkout(pool)
#     896         fairy._pool = pool
#     897         fairy._counter = 0
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:493, in _ConnectionRecord.checkout(cls, pool)
#     491 @classmethod
#     492 def checkout(cls, pool):
# --> 493     rec = pool._do_get()
#     494     try:
#     495         dbapi_connection = rec.get_connection()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:273, in Pool._create_connection(self)
#     270 def _create_connection(self):
#     271     """Called by subclasses to create a new ConnectionRecord."""
# --> 273     return _ConnectionRecord(self)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:388, in _ConnectionRecord.__init__(self, pool, connect)
#     386 self.__pool = pool
#     387 if connect:
# --> 388     self.__connect()
#     389 self.finalize_callback = deque()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:690, in _ConnectionRecord.__connect(self)
#     688     self.fresh = True
#     689 except BaseException as e:
# --> 690     with util.safe_reraise():
#     691         pool.logger.debug("Error on connect(): %s", e)
#     692 else:
#     693     # in SQLAlchemy 1.4 the first_connect event is not used by
#     694     # the engine, so this will usually not be set
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:686, in _ConnectionRecord.__connect(self)
#     684 try:
#     685     self.starttime = time.time()
# --> 686     self.dbapi_connection = connection = pool._invoke_creator(self)
#     687     pool.logger.debug("Created new connection %r", connection)
#     688     self.fresh = True
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/create.py:574, in create_engine.<locals>.connect(connection_record)
#     572         if connection is not None:
#     573             return connection
# --> 574 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/sqlalchemy/engine/default.py:598, in DefaultDialect.connect(self, *cargs, **cparams)
#     596 def connect(self, *cargs, **cparams):
#     597     # inherits the docstring from interfaces.Dialect.connect
# --> 598     return self.dbapi.connect(*cargs, **cparams)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     350     self._sock = None
#     351 else:
# --> 352     self.connect()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:636, in Connection.connect(self, sock)
#     633 self._next_seq_id = 0
#     635 self._get_server_information()
# --> 636 self._request_authentication()
#     638 if self.sql_mode is not None:
#     639     c = self.cursor()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:933, in Connection._request_authentication(self)
#     931 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     932 if self._auth_plugin_name == "caching_sha2_password":
# --> 933     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     934 elif self._auth_plugin_name == "sha256_password":
#     935     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/_auth.py:266, in caching_sha2_password_auth(conn, pkt)
#     263         print(conn.server_public_key.decode("ascii"))
#     265 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
# --> 266 pkt = _roundtrip(conn, data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/_auth.py:120, in _roundtrip(conn, send_data)
#     118 def _roundtrip(conn, send_data):
#     119     conn.write_packet(send_data)
# --> 120     pkt = conn._read_packet()
#     121     pkt.check_error()
#     122     return pkt
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}
